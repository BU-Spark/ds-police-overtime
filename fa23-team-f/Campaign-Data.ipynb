# %%
import pandas as pd
import matplotlib.pyplot as plt


#ocpf data too large to add to git, replace path with where it is stored locally on your machine
#for example if its in your downloads: 
ocpf = pd.read_csv('C:/Users/YOURNAME/Downloads/2010-2020 OCPF.csv')

activeCCContributions = pd.read_csv('./data/Campaign Contribution/Active_CC_Contributions.csv')

activeCCSummary = pd.read_csv('./data/Campaign Contribution/Active_Police_CC_Contributions.csv')

activePoliceCCContributions = pd.read_csv('./data/Campaign Contribution/Active_Police_CC_Contributions.csv')

allPoliceContributions = pd.read_csv('./data/Campaign Contribution/All Police Contributions.csv')

allCCContributions = pd.read_csv('./data/Campaign Contribution/All_CC_Contributions.csv')

allContWalsh = pd.read_csv('./data/Campaign Contribution/All_Cont_Walsh.csv')

allPoliceCC = pd.read_csv('./data/Campaign Contribution/All_Police_CC_Contributions.csv')

mayorWalshPolice = pd.read_csv('./data/Campaign Contribution/Mayor_Walsh_Police_Donations.csv')

# %% [markdown]
# <font size = "15">OCPF Data:</font>

# %%
ocpf
# Out:
#               Date                     Contributor              Address  \
# 0         1/1/2010                  Abber, Melissa  82 Jefferson Street
# 1         1/1/2010  Aggregated Unitemized Receipts                  NaN
# 2         1/1/2010  Aggregated Unitemized Receipts                  NaN
# 3         1/1/2010               Anderson, Deborah           Po Box 117
# 4         1/1/2010                    Aucoin, Rich  40 Cottage St Apt 3
# ...            ...                             ...                  ...
# 2237631  5/31/2020             Zegarra, Hermelinda        7 Westford St
# 2237632  5/31/2020             Zegarra, Hermelinda        7 Westford St
# 2237633  5/31/2020                    Zier, Kellie      23 Hillcrest Rd
# 2237634  5/31/2020                    Zier, Kellie      23 Hillcrest Rd
# 2237635  5/31/2020      Zuccarini Bickerton, Molly         181 TRAIN St
#
#                City State         Zip                  Occupation  \
# ...

# %%
ocpfPolice = ocpf[(ocpf['Employer'] == 'Boston Police Department' ) | (ocpf['Employer'] == 'BPD' )]
ocpfPolice
# Out:
#               Date           Contributor                 Address  \
# 15407    2/26/2010          RYLE, JOHN J        27 HAMPTON COURT
# 22458    3/10/2010       Brown, Joseph E          62 Dent Street
# 23623    3/11/2010      Fiandaca, Joseph          20 Herold Road
# 23823    3/11/2010  McElmoyle, Geraldine         9 Pinefield Rd.
# 41310     4/5/2010        Hanson, Sharon  11 Constellation Wharf
# ...            ...                   ...                     ...
# 2162698  2/28/2020       Parlon, William         8 Eastbourne St
# 2176269   3/6/2020         Coakley, Neva          39B Circuit St
# 2178517  3/12/2020      Callahan, Marian    20 Old Ironsides Way
# 2225825   5/9/2020        Noto, Thomas J       88 Myrtlebank Ave
# 2232860  5/29/2020   Snedeker, Catherine         30 Aldie Street
#
#                  City State         Zip          Occupation  \
# 15407    EAST WALPOLE    MA       02032      POLICE OFFICER
# 22458          Boston    MA       02132      Police Officer
# ...

# %%
#People Employed by City of Boston?
#Do we include 

cityOfBoston = ocpf[(ocpf['Employer'] == 'City Of Boston')]
cityOfBoston = cityOfBoston[(cityOfBoston['Occupation'] == 'Police Officer') | (cityOfBoston['Occupation'] == 'POLICE OFFICER') ]
cityOfBoston
# Out:
#                Date              Contributor               Address  \
# 54254     4/26/2010       JANKOWSKI, FRANCIS          191 TUDOR ST
# 54255     4/26/2010       JANKOWSKI, FRANCIS          191 TUDOR ST
# 701984    3/10/2014       Anderson , Lamont         24 Mariposa St
# 921434    2/28/2015              Litto, Rich        10 Brewster St
# 1007917   9/16/2015        Demarco, Robin A.           7 Roland St
# 1042087   11/2/2015       JANKOWSKI, FRANCIS          191 TUDOR ST
# 1104630    3/3/2016        Demarco, Robin A.           7 Roland St
# 1378834   6/15/2017        Abasciano, Joseph        337 Vermont St
# 1449564   9/27/2017  Jones-Henderson, Lylana          12 Morley St
# 1478266  10/26/2017           Moore, Charles  118 Ballou Ave, Fl 2
# 1733383   10/3/2018            Holmes, Brian            2 Irena Rd
# 1771977   11/2/2018        Stephens, Vincent          108 Devon St
# 1771978   11/2/2018     Stephens, Vincent H.      108 Devon Street
# ...

# %%
#Need to trop non police officer roles 
#Not sure how to go about because there can be captains and otehr positions

ocpfPolice['Occupation'].unique()
# Out:
# array(['POLICE OFFICER', 'Police Officer', 'Law Enforcement',
#        'Community Services', 'Chief of Staff', 'Officer', 'Detective',
#        nan, 'Retired', 'Cadet', 'police officer', 'POLICE LIEUTENANT',
#        'Police', 'Manager', 'Sr. Radio Tech.', 'Trainer',
#        'Boston Police Officer', 'Administrator', 'Sergeant Detective',
#        'Office Manager', 'ADMINISTRATOR', 'DETECTIVE', 'OFFICER',
#        '911 Operator', 'Boston Police Patrolman', 'City of Boston',
#        'Policeman', 'Police officer', 'Senior Radio Technician',
#        'Sergeant', 'Police Office', 'Admin', 'Police Officer, Gang Unit',
#        'Lieutenant Detective', 'law enforcement', 'LAW ENFORCEMENT',
#        'Deputy Superintendent', 'Office mgmr', 'Boston Police Det.',
#        'Police Sergeant', 'Admin secretary',
#        'Deputy Director Administration & Technology', 'Police Detective',
#        'Police Sergeant Detective', 'Lieutenant', 'Police Clerk',
# ...

# %%
ocpfPolice.isnull().sum()
# Out:
# Date                         0
# Contributor                  0
# Address                      1
# City                         1
# State                        0
# Zip                          2
# Occupation                   3
# Employer                     0
# Principal Officer          478
# Amount                       0
# CPF ID                       0
# Recipient                    0
# Tender Type ID               0
# Tender Type Description     28
# Record Type ID               0
# Record Type Description      0
# Source Description           0
# dtype: int64

# %%
ocpfPolice = ocpfPolice.sort_values(by = 'Amount', ascending = False)
ocpfPolice

#has negative amounts ...
# Out:
#                Date        Contributor               Address  \
# 1564842   3/15/2018     Ridge, Stephen     1 Schroeder Plaza
# 1679523    8/2/2018  Driscoll, Richard     16 Sylvester Road
# 1111111   3/18/2016     Brown, Michael      4 Preachers Path
# 1599400   4/27/2018   Cellucci, Tina M            18 Rita Rd
# 2056674  11/14/2019    McHale, Allison         171 Milton St
# ...             ...                ...                   ...
# 1879942   5/24/2019   Callahan, Marian  20 Old Ironsides Way
# 1857074   4/16/2019  Greenstein, Zelma         5 Sunset Ave.
# 1341595   4/26/2017         Awad, Rami      22 Franclaire Dr
# 1730344   9/28/2018    Parlon, William       8 Eastbourne St
# 1841602   3/22/2019    Parlon, William       8 Eastbourne St
#
#                       City State         Zip           Occupation  \
# 1564842             Boston    MA       02120            Detective
# 1679523         Dorchester    MA       02122       Police Officer
# ...

# %%
#remove negatives and total up the spending 

ocpfPolice = ocpfPolice[ocpfPolice['Amount'] >= 0]
total = ocpfPolice['Amount'].sum()
print("Total Spend in OCPF: " + str(total))
# Out:
# Total Spend in OCPF: 113444.56

# %%
#Did some people doname multiple times

print(ocpfPolice['Contributor'].value_counts())

#Try to figure out how much that person spent

spending = ocpfPolice.groupby('Contributor')['Amount'].sum()
spending.sort_values(ascending= False)
# Out:
# Young, Joseph         15
# Callahan, Marian      11
# McLaughlin, Kelli      9
# Driscoll, Richard      7
# Hosein, Haseeb         7
#                       ..
# Cohen , Mark A         1
# Lopes, Samora          1
# Anjos, Luis            1
# Cloherty, Joseph M     1
# Greenstein, Zelma      1
# Name: Contributor, Length: 268, dtype: int64
# Contributor
# Young, Joseph          5800.0
# Hosein, Haseeb         3500.0
# Driscoll, Richard      3200.0
# Medina, Richard        2750.0
# Brown, Michael         2750.0
#                         ...
# Griffiths , Brian J      25.0
# Delaney , Laura          25.0
# Awad 2016, Rami          20.0
# Xavier, Valdimir         20.0
# Greenstein, Zelma        10.0
# Name: Amount, Length: 268, dtype: float64

# %%
#Where did they donate 
print(ocpfPolice['Recipient'].value_counts())
spendingRecipient = ocpfPolice.groupby('Recipient')['Amount'].sum()
spendingRecipient.sort_values(ascending= False)
# Out:
# Walsh, Martin J.                           101
# Henning, Gregory                            39
# George, Annissa                             38
# Essaibi George, Annissa                     28
# Consalvo, Rob                               17
#                                           ...
# Rogers, John H.                              1
# Coppinger, Edward F.                         1
# Godfrey, Steven                              1
# Orrall, Keiko                                1
# MA Coalition of Nurse Practitioners PAC      1
# Name: Recipient, Length: 91, dtype: int64
# Recipient
# Walsh, Martin J.                           28917.0
# George, Annissa                            10000.0
# Henning, Gregory                            9350.0
# Essaibi George, Annissa                     7450.0
# Consalvo, Rob                               5000.0
#                                             ...
# Howell, Darrin D.                            100.0
# ...

# %% [markdown]
# <font size = "15">Active CC Contributions:</font>

# %%
activeCCContributions
# Out:
#             Date            Contributor                      Address  \
# 0      3/16/2010          ADAMSON, PAUL              17 LANDGRENE ST
# 1      3/16/2010         BELMONT, NANCY              294 ELMWOOD AVE
# 2      3/16/2010      BELMONT, WINIFRED              294 ELMWOOD AVE
# 3      3/16/2010        BERNINGER, MARY          156 SAINT ANDREW RD
# 4      3/16/2010            BOYLE, ANNA                 437 E 5TH ST
# ...          ...                    ...                          ...
# 38599   4/9/2020  Passacantilli, Daniel              328 Pond Street
# 38600   4/9/2020  Petruzziello, Armando  20 Milton Street, Suite 109
# 38601   4/9/2020         Starikov, Fred              91 Osborne Path
# 38602   4/9/2020            Tobin, John                 60 Belle Ave
# 38603   4/9/2020            Tobin, John                 60 Belle Ave
#
#                City State         Zip             Occupation  \
# 0          SQUANTUM    MA  02171-1307  REAL ESTATE DEVELOPER
# ...

# %%
activeCCContributionsP = activeCCContributions[ (activeCCContributions['Employer'] == 'Boston Police Department' ) | (activeCCContributions['Employer'] == 'BPD' )]
activeCCContributionsP
# Out:
#              Date          Contributor            Address          City State  \
# 2341    11/6/2013     Delaney , Laura      64 Redfield St    Dorchester    MA
# 2671    5/29/2014     Walsh , Brendan        294 W 5th St  South Boston    MA
# 3686   10/15/2015     Delaney, Laura A     64 Redfield St        Boston    MA
# 5140    9/22/2017    Stoddard, James M  665 E 6th St, # 2  South Boston    MA
# 7072    11/5/2019  Snedeker, Catherine   30 Aldie St, # 2       Allston    MA
# ...           ...                  ...                ...           ...   ...
# 37993   3/22/2019      Parlon, William    8 Eastbourne St    Roslindale    MA
# 37994   3/22/2019      Parlon, William    8 Eastbourne St    Roslindale    MA
# 38089   5/16/2019     Dougherty, Janet    34 Gretter Road  West Roxbury    MA
# 38126   5/16/2019      Parlon, William    8 Eastbourne St    Roslindale    MA
# 38591   2/28/2020      Parlon, William    8 Eastbourne St    Roslindale    MA
#
# ...

# %%
#People employed by city of Boston

cityOfBoston = activeCCContributions[(activeCCContributions['Employer'] == 'City Of Boston') | (activeCCContributions['Employer'] == 'CITY OF BOSTON')]
cityOfBoston = cityOfBoston[(cityOfBoston['Occupation'] == 'Police Officer') | (cityOfBoston['Occupation'] == 'POLICE OFFICER') ]
cityOfBoston
# Out:
#             Date             Contributor                Address        City  \
# 149    5/28/2010           STUDLEY, JOHN       19 BOUTWELL ST 2      BOSTON
# 330    5/27/2011         STUDLEY, JOHN M       19 BOUTWELL ST 2      BOSTON
# 456     8/3/2011  LOAN, JR, JOHN FRANCIS           431 E 6TH ST      BOSTON
# 538    8/24/2011      PAROLIN, MAUREEN E  664 EAST 7TH STREET 3      BOSTON
# 649    9/23/2011     WALL, JR, LEONARD F         48 COOLIDGE RD      MILTON
# 779   10/13/2011  COUGHLIN, PAUL MATTHEW          50 MILWOOD ST  DORCHESTER
# 809   10/13/2011   GIARDINA, SR, JAMES V       6 GOODALE STREET     PEABODY
# 1021  10/29/2011        MURPHY, DENNIS J         25 STAFFORD RD    WESTWOOD
# 1101  11/14/2011         GREENE, BERNARD          370 BEACON ST      BOSTON
#
#      State        Zip      Occupation        Employer Principal Officer  \
# 149     MA  021222513  POLICE OFFICER  CITY OF BOSTON               NaN
# ...

# %%
activeCCContributionsP.isnull().sum()
# Out:
# Date                         0
# Contributor                  0
# Address                      0
# City                         0
# State                        0
# Zip                          0
# Occupation                   0
# Employer                     0
# Principal Officer          113
# Amount                       0
# CPF ID                       0
# Recipient                    0
# Tender Type ID               0
# Tender Type Description      0
# Record Type ID               0
# Record Type Description      0
# Source Description           0
# Datetime                     0
# UUID                         0
# dtype: int64

# %%
activeCCContributionsP = activeCCContributionsP.sort_values(by = 'Amount', ascending = False)
activeCCContributionsP
# Out:
#              Date        Contributor               Address         City State  \
# 16362    8/2/2018  Driscoll, Richard     16 Sylvester Road   Dorchester    MA
# 32160   7/19/2019   Francis, Anthony      7 Ruthven Street       Boston    MA
# 14420  10/19/2013    Medina, Melissa       8 Norton Street       Boston    MA
# 15790    6/6/2017    Medina, Richard       8 Norton Street    Hyde Park    MA
# 31208  11/14/2019     Hosein, Haseeb       505 Harland St.       Milton    MA
# ...           ...                ...                   ...          ...   ...
# 20491  10/13/2017   Callahan, Marian  20 Old Ironsides Way  Charlestown    MA
# 2341    11/6/2013   Delaney , Laura         64 Redfield St   Dorchester    MA
# 21718   5/24/2019   Callahan, Marian  20 Old Ironsides Way  Charlestown    MA
# 37794   9/28/2018    Parlon, William       8 Eastbourne St   Roslindale    MA
# 37994   3/22/2019    Parlon, William       8 Eastbourne St   Roslindale    MA
#
# ...

# %%
activeCCContributionsP = activeCCContributionsP[activeCCContributionsP['Amount'] >= 0]
total = activeCCContributionsP['Amount'].sum()
print("Total Spend in active CC Contributions: " + str(total))
# Out:
# Total Spend in active CC Contributions: 24721.0

# %%
#Did some people doname multiple times

print(activeCCContributionsP['Contributor'].value_counts())

#Try to figure out how much that person spent

spending = activeCCContributionsP.groupby('Contributor')['Amount'].sum()
spending.sort_values(ascending= False)
# Out:
# Callahan, Marian         11
# Driscoll, Richard         6
# Medina, Richard           6
# Baston, Nora              6
# Parlon, William           5
# Leahy, Brian              4
# McGrath, Doug             4
# Noto, Thomas              4
# Lacroix, James            4
# Barrett, Dana             4
# Curry, Carmen             3
# Burke, Terrence           3
# Morris, Matthew           3
# Dougherty, Janet          3
# Hosein, Haseeb            3
# Kelly, Brendan            2
# Callow, Keith             2
# Boulger, Michael          2
# Dineen, John              2
# Donovan, Michael          2
# Brown, Michael            2
# Lopez, Luis               1
# Delaney, Laura A          1
# Marrero, Eliseo           1
# Leahy, Thomas             1
# Broderick, John           1
# Benton, Jeremiah          1
# Stoddard, James M         1
# Medina, Melissa           1
# Bellew, Mary              1
# Monteiro, Agnaldo         1
# Casper, Paula             1
# Walsh , Brendan           1
# ...

# %%
#Where did they donate 
print(activeCCContributionsP['Recipient'].value_counts())
spendingRecipient = activeCCContributionsP.groupby('Recipient')['Amount'].sum()
spendingRecipient.sort_values(ascending= False)
# Out:
# George, Annissa             38
# Essaibi George, Annissa     28
# Edwards, Lydia              11
# O'Malley, Matthew J.         8
# Mejia, Julia M.              6
# Wu, Michelle                 5
# Flaherty Jr., Michael F.     5
# Janey, Kim                   3
# Flynn, Edward Michael        3
# Arroyo, Ricardo N.           2
# Campbell, Andrea Joy         2
# Name: Recipient, dtype: int64
# Recipient
# George, Annissa             10000.0
# Essaibi George, Annissa      7450.0
# O'Malley, Matthew J.         1339.0
# Wu, Michelle                 1250.0
# Janey, Kim                   1200.0
# Mejia, Julia M.              1050.0
# Arroyo, Ricardo N.           1000.0
# Campbell, Andrea Joy          500.0
# Flaherty Jr., Michael F.      400.0
# Edwards, Lydia                332.0
# Flynn, Edward Michael         200.0
# Name: Amount, dtype: float64

# %%
#Some of the entries are the same 
merged = pd.merge(ocpfPolice, activeCCContributionsP, how='outer', indicator='merge1')

#these were the same
same_rows = merged[merged['merge1'] == 'both']
same_rows
# Out:
#            Date        Contributor                   Address         City  \
# 1      8/2/2018  Driscoll, Richard         16 Sylvester Road   Dorchester
# 17   12/13/2016  Driscoll, Richard         16 Sylvester Road   Dorchester
# 19   12/13/2016    Medina, Richard           8 Norton Street    Hyde Park
# 20   12/13/2016      Barrett, Dana  53 Summit Street, Apt. 1    Hyde Park
# 28     6/8/2016    Medina, Richard           8 Norton Street    Hyde Park
# ..          ...                ...                       ...          ...
# 462  10/13/2017   Callahan, Marian      20 Old Ironsides Way  Charlestown
# 466  12/23/2018   Odom Sr., Ronald          74 Corbet Street   Dorchester
# 467   2/13/2019    Correia, Sylvia            23 Duke Street       Boston
# 470   6/14/2019   Callahan, Marian      20 Old Ironsides Way  Charlestown
# 475   5/24/2019   Callahan, Marian      20 Old Ironsides Way  Charlestown
#
#     State         Zip        Occupation                  Employer  \
# ...

# %% [markdown]
# <font size = "15">Active CC Summary:</font>

# %%
activeCCSummary
# Out:
#                    Address  Amount  CPF ID          City  \
# 0         19 BOUTWELL ST 2   100.0   12892        BOSTON
# 1         19 BOUTWELL ST 2   500.0   12892        BOSTON
# 2             431 E 6TH ST   100.0   12892        BOSTON
# 3    664 EAST 7TH STREET 3   500.0   12892        BOSTON
# 4           48 COOLIDGE RD   200.0   12892        MILTON
# ..                     ...     ...     ...           ...
# 555        8 Eastbourne St   139.0   14092    Roslindale
# 556        8 Eastbourne St   200.0   14092    Roslindale
# 557        34 Gretter Road   250.0   14092  West Roxbury
# 558        8 Eastbourne St   100.0   14092    Roslindale
# 559        8 Eastbourne St   100.0   14092    Roslindale
#
#                 Contributor       Date    Datetime                  Employer  \
# 0             STUDLEY, JOHN  5/28/2010  2010-05-28            CITY OF BOSTON
# 1           STUDLEY, JOHN M  5/27/2011  2011-05-27            CITY OF BOSTON
# ...

# %%
activeCCSummaryPolice = activeCCSummary[ (activeCCSummary['Employer'] == 'City Of Boston') | (activeCCSummary['Employer'] == 'Boston Police Department' ) | (activeCCSummary['Employer'] == 'BPD' ) | (activeCCSummary['Employer'] == 'CITY OF BOSTON') |
                                         (activeCCSummary['Employer'] == 'BOSTON POLICE DEPT') | (activeCCSummary['Employer'] == 'CITY OF BOSTON') | (activeCCSummary['Employer'] == 'CITY OF BOSTON')]
activeCCSummaryPolice
# Out:
#                    Address  Amount  CPF ID          City  \
# 0         19 BOUTWELL ST 2   100.0   12892        BOSTON
# 1         19 BOUTWELL ST 2   500.0   12892        BOSTON
# 2             431 E 6TH ST   100.0   12892        BOSTON
# 3    664 EAST 7TH STREET 3   500.0   12892        BOSTON
# 4           48 COOLIDGE RD   200.0   12892        MILTON
# ..                     ...     ...     ...           ...
# 555        8 Eastbourne St   139.0   14092    Roslindale
# 556        8 Eastbourne St   200.0   14092    Roslindale
# 557        34 Gretter Road   250.0   14092  West Roxbury
# 558        8 Eastbourne St   100.0   14092    Roslindale
# 559        8 Eastbourne St   100.0   14092    Roslindale
#
#                 Contributor       Date    Datetime                  Employer  \
# 0             STUDLEY, JOHN  5/28/2010  2010-05-28            CITY OF BOSTON
# 1           STUDLEY, JOHN M  5/27/2011  2011-05-27            CITY OF BOSTON
# ...

# %%
activeCCSummaryPolice.isnull().sum()
# Out:
# Address                      0
# Amount                       0
# CPF ID                       0
# City                         0
# Contributor                  0
# Date                         0
# Datetime                     0
# Employer                     0
# Occupation                   0
# Principal Officer          119
# Recipient                    0
# Record Type Description      0
# Record Type ID               0
# Source Description           0
# State                        0
# Tender Type Description      0
# Tender Type ID               0
# UUID                         0
# Zip                          0
# dtype: int64

# %%
activeCCSummaryPolice = activeCCSummaryPolice.sort_values(by = 'Amount', ascending = False)
activeCCSummaryPolice
# Out:
#                          Address  Amount  CPF ID         City  \
# 311            16 Sylvester Road  1000.0   15618   Dorchester
# 289            16 Sylvester Road   500.0   15618   Dorchester
# 490           50 Moreland Street   500.0   16537      Roxbury
# 286     53 Summit Street, Apt. 1   500.0   15618    Hyde Park
# 488          54 Richfield Street   500.0   17105       Boston
# ..                           ...     ...     ...          ...
# 374         20 Old Ironsides Way    25.0   16314  Charlestown
# 377         20 Old Ironsides Way    25.0   16314  Charlestown
# 380  19 Old Ironsides Way, Apt B    25.0   16314  Charlestown
# 381         20 Old Ironsides Way    25.0   16314  Charlestown
# 376         20 Old Ironsides Way    15.0   16314  Charlestown
#
#            Contributor        Date    Datetime                  Employer  \
# 311  Driscoll, Richard    8/2/2018  2018-08-02  Boston Police Department
# ...

# %%
total = activeCCSummaryPolice['Amount'].sum()
print("Total Spend in active CC summary: " + str(total))
# Out:
# Total Spend in active CC summary: 26421.0

# %%
#Where did they donate 
print(activeCCSummaryPolice['Recipient'].value_counts())
# Out:
# Essaibi George, Annissa     65
# Flaherty Jr., Michael F.    15
# Edwards, Lydia              11
# O'Malley, Matthew J.         8
# Mejia, Julia M.              6
# Wu, Michelle                 5
# Janey, Kim                   3
# Flynn, Edward Michael        3
# Campbell, Andrea Joy         2
# Arroyo, Ricardo N.           1
# Name: Recipient, dtype: int64

# %%
#More idenitical entries?

#Some of the entries are the same 
merged2 = pd.merge(merged, activeCCSummaryPolice, how='inner', indicator='merge2')

#these were the same
same_rows = merged2[merged2['merge1'] == 'both']
same_rows
# Out:
#           Date        Contributor               Address         City State  \
# 0     8/2/2018  Driscoll, Richard     16 Sylvester Road   Dorchester    MA
# 1    4/27/2017       Smart, Jerry    50 Moreland Street      Roxbury    MA
# 2     6/6/2017    Medina, Richard       8 Norton Street    Hyde Park    MA
# 3   12/17/2018     Hosein, Haseeb    505 Harland Street       Milton    MA
# 4   12/29/2018    Marrero, Eliseo   54 Richfield Street       Boston    MA
# ..         ...                ...                   ...          ...   ...
# 67  10/13/2017   Callahan, Marian  20 Old Ironsides Way  Charlestown    MA
# 68  12/23/2018   Odom Sr., Ronald      74 Corbet Street   Dorchester    MA
# 69   2/13/2019    Correia, Sylvia        23 Duke Street       Boston    MA
# 70   6/14/2019   Callahan, Marian  20 Old Ironsides Way  Charlestown    MA
# 71   5/24/2019   Callahan, Marian  20 Old Ironsides Way  Charlestown    MA
#
# ...

# %% [markdown]
# <font size = "15">Active CC Police Contributions:</font>

# %%
#This should be the same as what we found before?

activePoliceCCContributions
# Out:
#                    Address  Amount  CPF ID          City  \
# 0         19 BOUTWELL ST 2   100.0   12892        BOSTON
# 1         19 BOUTWELL ST 2   500.0   12892        BOSTON
# 2             431 E 6TH ST   100.0   12892        BOSTON
# 3    664 EAST 7TH STREET 3   500.0   12892        BOSTON
# 4           48 COOLIDGE RD   200.0   12892        MILTON
# ..                     ...     ...     ...           ...
# 555        8 Eastbourne St   139.0   14092    Roslindale
# 556        8 Eastbourne St   200.0   14092    Roslindale
# 557        34 Gretter Road   250.0   14092  West Roxbury
# 558        8 Eastbourne St   100.0   14092    Roslindale
# 559        8 Eastbourne St   100.0   14092    Roslindale
#
#                 Contributor       Date    Datetime                  Employer  \
# 0             STUDLEY, JOHN  5/28/2010  2010-05-28            CITY OF BOSTON
# 1           STUDLEY, JOHN M  5/27/2011  2011-05-27            CITY OF BOSTON
# ...

# %%
activePoliceCCContributions['Employer'].unique()

# activePoliceCCContributionsBoston = activePoliceCCContributions[ (activePoliceCCContributions['Employer'] == 'City Of Boston') | (activePoliceCCContributions['Employer'] == 'Boston Police Department' ) | (activePoliceCCContributions['Employer'] == 'BPD' )]
# activePoliceCCContributionsBoston

activePoliceCCContributionsBoston = activePoliceCCContributions[ (activePoliceCCContributions['Employer'] == 'City Of Boston') | (activePoliceCCContributions['Employer'] == 'Boston Police Department' ) | (activePoliceCCContributions['Employer'] == 'BPD' ) | (activePoliceCCContributions['Employer'] == 'CITY OF BOSTON') |
                                         (activePoliceCCContributions['Employer'] == 'BOSTON POLICE DEPT') | (activePoliceCCContributions['Employer'] == 'CITY OF BOSTON') | (activePoliceCCContributions['Employer'] == 'CITY OF BOSTON')]

# activePoliceCCContributionsBoston
# Out:
# array(['CITY OF BOSTON', 'BOSTON POLICE DEPT.', 'City of Boston',
#        'Tufts University', 'City of  Boston', 'Boston Police Dept.',
#        'City of boston', 'City of Quincy', 'Bha', 'Boston Police', 'Bpd',
#        'BPD', 'BHA', 'Retired', 'city of bsoton',
#        'Boston Police Department', 'BDP', 'State Police',
#        'Boston Police dept', 'Boston police', 'Boston',
#        'Commonwealth of Mass', 'Deputy Sheriff', 'City ofboston',
#        'Commonwealth of Mass.', 'Mass State Police',
#        "Boston Police Patrolmens' Association",
#        "Boston Police Patrolmen's Association", 'MBTA', 'City Boston',
#        'Suffolk County', 'Suffolk County Sheriff Department',
#        'City of Boston Police Dept', 'Boston Public Schools', 'Boston PD',
#        'BPS', 'Quincy Police Department', 'Federal Protective Service',
#        'Commonwealth of Massachusetts', 'DPH',
#        "Suffolk County Sheriff's Department", 'City of Chicago',
# ...

# %%
activePoliceCCContributionsBoston['Occupation'].unique()
# Out:
# array(['POLICE OFFICER', 'POLICE OFFICE', 'police officer',
#        'Police Officer', 'Detective', 'Admin', 'Boston Police Officer',
#        'Boston Police Det.', 'Police Detective', 'Boston Police',
#        'Police Officer (2019 Contribution)', 'Crossing Guard',
#        'Telecommunications Operator', 'Police', 'Police Officer ',
#        '911 Call Taker', 'Research Anaylst', 'Administrative Aide',
#        'Captain', 'Administration'], dtype=object)

# %% [markdown]
# I think these are the occupations we will need to prune all of the data after filtering to BPD as employer

# %%
activePoliceCCContributionsBoston.isnull().sum()
# Out:
# Address                      0
# Amount                       0
# CPF ID                       0
# City                         0
# Contributor                  0
# Date                         0
# Datetime                     0
# Employer                     0
# Occupation                   0
# Principal Officer          119
# Recipient                    0
# Record Type Description      0
# Record Type ID               0
# Source Description           0
# State                        0
# Tender Type Description      0
# Tender Type ID               0
# UUID                         0
# Zip                          0
# dtype: int64

# %%
activePoliceCCContributionsBoston = activePoliceCCContributionsBoston.sort_values(by = 'Amount', ascending = False)
activePoliceCCContributionsBoston
# Out:
#                          Address  Amount  CPF ID         City  \
# 311            16 Sylvester Road  1000.0   15618   Dorchester
# 289            16 Sylvester Road   500.0   15618   Dorchester
# 490           50 Moreland Street   500.0   16537      Roxbury
# 286     53 Summit Street, Apt. 1   500.0   15618    Hyde Park
# 488          54 Richfield Street   500.0   17105       Boston
# ..                           ...     ...     ...          ...
# 374         20 Old Ironsides Way    25.0   16314  Charlestown
# 377         20 Old Ironsides Way    25.0   16314  Charlestown
# 380  19 Old Ironsides Way, Apt B    25.0   16314  Charlestown
# 381         20 Old Ironsides Way    25.0   16314  Charlestown
# 376         20 Old Ironsides Way    15.0   16314  Charlestown
#
#            Contributor        Date    Datetime                  Employer  \
# 311  Driscoll, Richard    8/2/2018  2018-08-02  Boston Police Department
# ...

# %%
total = activePoliceCCContributionsBoston['Amount'].sum()
print("Total Spend in active police CC Contributions: " + str(total))
# Out:
# Total Spend in active police CC Contributions: 26421.0

# %%
#Where did they donate 
print(activePoliceCCContributionsBoston['Recipient'].value_counts())
# Out:
# Essaibi George, Annissa     65
# Flaherty Jr., Michael F.    15
# Edwards, Lydia              11
# O'Malley, Matthew J.         8
# Mejia, Julia M.              6
# Wu, Michelle                 5
# Janey, Kim                   3
# Flynn, Edward Michael        3
# Campbell, Andrea Joy         2
# Arroyo, Ricardo N.           1
# Name: Recipient, dtype: int64

# %% [markdown]
# <font size = "15">All Police Contributions:</font>

# %%
allPoliceContributions
# Out:
#                     Address  Amount  CPF ID            City  \
# 0                22 WEST ST   100.0   13237   NEWTON CORNER
# 1               71 GROVE CR   100.0   13284       BRAINTREE
# 2             Ricca Farm Rd   200.0   15274       Billerica
# 3             8 Skipper Way   200.0   10419      Gloucester
# 4          156 Chuckles Way   100.0   14944  Marstons Mills
# ...                     ...     ...     ...             ...
# 10363           214 Read St   250.0   13597      Fall River
# 10364  20 Old Ironsides Way    25.0   16314     Charlestown
# 10365       14 Brierwood Rd   500.0   15960       Braintree
# 10366    24 Washburn Ave #1   100.0   13645       Cambridge
# 10367       30 Aldie Street   125.0   13645         Allston
#
#                 Contributor       Date    Datetime  \
# 0      CICCONE, JR, ALLAN L   1/7/2010  2010-01-07
# 1          LINSKEY, MICHAEL  1/10/2010  2010-01-10
# 2          Haffner, William  1/21/2010  2010-01-21
# ...

# %%
allPoliceContributions['Employer'].unique()

allPoliceContributionsBoston = allPoliceContributions[ (allPoliceContributions['Employer'] == 'City Of Boston') | (allPoliceContributions['Employer'] == 'Boston Police Department' ) | (allPoliceContributions['Employer'] == 'BPD' )]
allPoliceContributionsBoston
# Out:
# array(['TOWN OF SHERBORN', nan, 'City of Medford', ...,
#        'springfield police', 'Brockton Police Dept.',
#        'Retired Police Officer'], dtype=object)

# %%
allPoliceContributionsBoston['Occupation'].unique()
# Out:
# array(['POLICE OFFICER', 'Police Officer', 'Police Detective',
#        'police officer', 'POLICE LIEUTENANT', 'Police',
#        'Boston Police Officer', 'Boston Police Patrolman', 'Policeman',
#        'Police officer', 'Police Office', 'Police Officer, Gang Unit',
#        'Boston Police Det.', 'Police Sergeant',
#        'Police Sergeant Detective', 'Police Clerk', 'Police Sargeant',
#        'Police Lieutenant', 'Police Department',
#        'Boston Police Detective', 'Police Office ',
#        'Retired Police Sargeant', 'Boston Police',
#        'Police Officer (2019 Contribution)', 'Police Officer ',
#        'Law Enforcement', 'law enforcement', 'LAW ENFORCEMENT',
#        'Law Enforcement Officer', 'Detective', 'Sergeant Detective',
#        'DETECTIVE', 'Lieutenant Detective', 'Retired Captain Detective',
#        'Sgt. Detective', 'Lt. Detective', 'Lieutenant/detective', nan,
#        'Manager', 'Trainer', 'Administrator', 'Office Manager',
# ...

# %%
allPoliceContributionsBoston.isnull().sum()
# Out:
# Address                      1
# Amount                       0
# CPF ID                       0
# City                         1
# Contributor                  0
# Date                         0
# Datetime                     0
# Employer                     0
# Occupation                   3
# Principal Officer          467
# Recipient                    0
# Record Type Description      0
# Record Type ID               0
# Source Description           0
# State                        0
# Tender Type Description     27
# Tender Type ID               0
# UUID                         0
# Zip                          2
# dtype: int64

# %%
allPoliceContributionsBoston = allPoliceContributionsBoston.sort_values(by = 'Amount', ascending = False)
allPoliceContributionsBoston
# Out:
#                     Address  Amount  CPF ID               City  \
# 6413    16 Saint Brendan Rd  1000.0   14902         Dorchester
# 3770       4 Preachers Path  1000.0   13173         Marshfield
# 5860      16 Sylvester Road  1000.0   15618         Dorchester
# 6747          171 Milton St  1000.0   13173  Dorchester Center
# 6251            179 Main St  1000.0   13173         Marshfield
# ...                     ...     ...     ...                ...
# 1741    39 Vassar Street #1    20.0   15609             Boston
# 4386       22 Franclaire Dr    20.0   13173       West Roxbury
# 10299  20 Old Ironsides Way    15.0   16314        Charlestown
# 10288         5 Sunset Ave.    10.0   80760            Reading
# 4595       22 Franclaire Dr     3.0   13173       West Roxbury
#
#              Contributor        Date    Datetime                  Employer  \
# 6413       Young, Joseph   5/30/2019  2019-05-30  Boston Police Department
# ...

# %%
total = allPoliceContributionsBoston['Amount'].sum()
print("Total Spend All Police Contributions: " + str(total))
# Out:
# Total Spend All Police Contributions: 113054.56

# %%
#Where did they donate 
print(allPoliceContributionsBoston['Recipient'].value_counts())
# Out:
# Walsh, Martin J.                           98
# Henning, Gregory                           39
# George, Annissa                            37
# Essaibi George, Annissa                    28
# Linehan, William 'Bill'                    17
#                                            ..
# Costello, Sean P.                           1
# Orrall, Keiko                               1
# Crawford, Jamarhl C                         1
# Godfrey, Steven                             1
# MA Coalition of Nurse Practitioners PAC     1
# Name: Recipient, Length: 91, dtype: int64

# %% [markdown]
# <font size = "15">All CC Contributions:</font>

# %% [markdown]
# <font size = "15">All Walsh Contributions:</font>

# %% [markdown]
# <font size = "15">All Police CC Contributions:</font>

# %% [markdown]
# <font size = "15">Walsh Police Donations:</font>
