# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import Data
overtime21 = pd.read_csv('./data/Overtime/2021_Details.xlsx - _2021_Detals.csv')

overtime_court21 = pd.read_excel('./data/Overtime/Court_Overtime_2021_-_2022_ytd.xlsx')

overtime_police_record = pd.read_excel('./data/Overtime/Police_Record_Request_Jan_2019_to_present.xlsx')

earnings21 = pd.read_csv('./data/Earnings/finalconsolidatedcy22earnings_feb2023.xlsx-sheet1.csv')

# %% [markdown]
# ### Overtime and Overtime_court can be merged by Emp.ID and ID
#
# ### But earnings data has no ID so matching by name seems like the best way
#
# ### I think Rank in overtime data has close relationship with Title.

# %%
overtime21.head()
# Out:
#    Tracking_No  Emp. ID           Employee  Rank          Street xStreet  \
# 0      2343189   140298       GARNEY,BRIAN     9  NEW CHARDON ST     NaN
# 1      2343190    10264           GAVA,ROY     9  NEW CHARDON ST     NaN
# 2      2338683     9707  BOYLE,FREDERICK J     9     LOMASNEY WY     NaN
# 3      2340857   116235     JOSEPH,GREGORY     9     LONGWOOD AV     NaN
# 4      2343951    12253      BUTLER,BOBBIE     9    BLUE HILL AV     NaN
#
#   Detail\r\nDate  Start\r\nTime  End \r\nTime  Hours\r\nWorked  Hours\r\nPaid  \
# 0       1/2/2021            700           800              100              4
# 1       1/2/2021            700           800              100              4
# 2       1/2/2021            700          1200              500              8
# 3       1/1/2021            800          1530              730              8
# 4       1/1/2021            900          1500              600              8
#
#   Type  Customer No.                    Customer     Customer Address  \
# 0    C          2838      MORIARTY, JOHN & ASSOC      3 CHURCH STREET
# 1    C          2838      MORIARTY, JOHN & ASSOC      3 CHURCH STREET
# 2    C          2602   TISHMAN CONSTRUCTION CORP    1 FEDERAL ST FL 8
# 3    S           151  CHILDREN'S HOSPITAL BOSTON  300 LONGWOOD AVENUE
# 4    C           396               NATIONAL GRID       40 SYLVAN ROAD
#
#             Customer Address 1 Customer Address 3 Customer_City  \
# 0                          NaN                NaN    WINCHESTER
# 1                          NaN                NaN    WINCHESTER
# 2                          NaN                NaN        BOSTON
# 3  ATTN:BOB RYAN,SECURITY DEPT                NaN        BOSTON
# 4          ATTN: MARY MULRONEY                NaN       WALTHAM
#
#   Customer_State Customer_zip
# 0             MA        01890
# 1             MA        01890
# 2             MA        02110
# 3             MA        02115
# 4             MA        02451

# %%
overtime_court21.head()
# Out:
#        ID              NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0  153088       Chen,Steven  Ptl       DISTRICT 01       DISTRICT 01
# 1   53603     Gero,Jarrod A  Det  B-2   DETECTIVES  B-2   DETECTIVES
# 2   11716  McCarthy,Peter L  Det  B-3   DETECTIVES  B-3   DETECTIVES
# 3  157666     Mejia,Karen Y  Ptl       DISTRICT 01       DISTRICT 01
# 4   12045  Merricks,Kirk D.  Ptl       DISTRICT 01       DISTRICT 01
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2021-01-05   281.0  COURT:CLERK MAG. HRG        900      930     0.50
# 1 2021-01-06   283.0    COURT:MOTIONS HRG.       1130     1230     1.00
# 2 2021-01-04   286.0      COURT:CASE PREP.       1600     1730     1.50
# 3 2021-01-04   281.0  COURT:CLERK MAG. HRG        900      930     0.50
# 4 2021-01-05   281.0  COURT:CLERK MAG. HRG        900      915     0.25
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
overtime_police_record.head(10)
# Out:
#     IDNO6                 NAME    RANK                ASSIGNED_DESC  \
# 0   10525         Davin,John J    Capt  SPECIAL OPERATIONS DIVISION
# 1   10273        Hosein,Haseeb    Capt                  DISTRICT 03
# 2    8368      Terenzi,Phillip    Capt          OPERATIONS DIVISION
# 3  115669      Auclair,Richard  Civili           LATENT PRINTS UNIT
# 4  113177     Cardona,Veronica  Civili          OPERATIONS DIVISION
# 5   80561       Collins,Dianna  Civili          OPERATIONS DIVISION
# 6   90489     Correia,Sylvia L  Civili          OPERATIONS DIVISION
# 7  143367  Fredericks,Jennifer  Civili                        BRIC
# 8   99560    Garcia,Jazdiannet  Civili          OPERATIONS DIVISION
# 9   75005          Green,Derek  Civili       BUILDING SECURITY UNIT
#
#           CHARGED_DESC     OTDATE  OTCODE           DESCRIPTION  STARTTIME  \
# 0  TACTICAL OPERATIONS 2019-01-01     271            ENTRY TEAM        130
# 1          DISTRICT 03 2019-01-01     212   CRIME SCENE INVEST.        315
# 2  OPERATIONS DIVISION 2019-01-01     325  COMPLETE TOUR ASSIGN       1600
# 3   LATENT PRINTS UNIT 2019-01-01     261    ADD. WORK ASSIGNED       1700
# 4  OPERATIONS DIVISION 2019-01-01     261    ADD. WORK ASSIGNED          0
# 5  OPERATIONS DIVISION 2019-01-01     111            SICK LEAVE        800
# 6  OPERATIONS DIVISION 2019-01-01     112        VACATION LEAVE       1600
# 7   INTELLIGENCE GROUP 2019-01-01     261    ADD. WORK ASSIGNED        900
# 8  OPERATIONS DIVISION 2019-01-01     261    ADD. WORK ASSIGNED          0
# 9  OPERATIONS DIVISION 2019-01-01     261    ADD. WORK ASSIGNED        600
#
#    ENDTIME  WRKDHRS  OTHOURS
# 0      600      4.5      4.5
# 1      515      2.0      4.0
# 2     1900      3.0      3.0
# 3     2000      3.0      3.0
# 4      400      4.0      4.0
# 5     1600      8.0      8.0
# 6        0      8.0      8.0
# 7     1700      8.0      8.0
# 8      400      4.0      4.0
# 9     1000      4.0      4.0

# %%
earnings21.head()
# Out:
#                 NAME           DEPARTMENT_NAME                    TITLE  \
# 0     Gavin,Donna M.  Boston Police Department  Police Lieutenant (Det)
# 1  Cassellius,Brenda            Superintendent           Superintendent
# 2       Dempsey,John    Boston Fire Department       Commissioner (BFD)
# 3   Demesmin,Stanley  Boston Police Department  Police Lieutenant (Det)
# 4       Smith,Sean P  Boston Police Department        Police Lieutenant
#
#       REGULAR RETRO         OTHER    OVERTIME INJURED     DETAIL  \
# 0   53,226.90   NaN  1,045,845.44      463.52     NaN        NaN
# 1  179,109.61   NaN    417,839.83         NaN     NaN        NaN
# 2  133,653.78   NaN    312,752.53         NaN     NaN        NaN
# 3  145,775.26   NaN     13,932.92  196,515.25     NaN  11,880.00
# 4  142,535.62   NaN     18,827.45  142,692.38     NaN  46,365.00
#
#   QUINN_EDUCATION  TOTAL_ GROSS POSTAL
# 0       12,812.39  1,112,348.25  02186
# 1             NaN    596,949.44  55419
# 2             NaN    446,406.31  02152
# 3       29,155.26    397,258.69  02052
# 4       35,633.88    386,054.33  02186

# %% [markdown]
# ### How do we deal with missing data?

# %%
print('overtime21')
overtime21.isnull().sum()

print('overtime_court21')
overtime_court21.isnull().sum()

print('earnings21')
earnings21.isnull().sum()
# Out:
# overtime21
# overtime_court21
# earnings21
# NAME                   0
# DEPARTMENT_NAME        0
# TITLE                  0
# REGULAR              600
# RETRO              20112
# OTHER               7378
# OVERTIME           16392
# INJURED            21983
# DETAIL             21088
# QUINN_EDUCATION    21835
# TOTAL_ GROSS           0
# POSTAL                 0
# dtype: int64

# %%
overtime21.columns
# Out:
# Index(['Tracking_No', 'Emp. ID', 'Employee', 'Rank', 'Street', 'xStreet',
#        'Detail\r\nDate', 'Start\r\nTime', 'End \r\nTime', 'Hours\r\nWorked',
#        'Hours\r\nPaid', 'Type', 'Customer No.', 'Customer', 'Customer Address',
#        'Customer Address 1', 'Customer Address 3', 'Customer_City',
#        'Customer_State', 'Customer_zip'],
#       dtype='object')

# %%
temp_overtime21 = overtime21.copy()
temp_overtime21.sort_values(by=['Emp. ID', 'Detail\r\nDate'], inplace=True)

temp_overtime21.head(20)
# Out:
#        Tracking_No  Emp. ID             Employee  Rank           Street  \
# 28182      2394989     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 28564      2395199     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 36828      2407064     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 35197      2408406     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 36606      2413502     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 37551      2414375     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 38173      2414034     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 45370      2434574     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 51734      2450059     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 52116      2451768     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 52389      2450359     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 49157      2445795     8191    TORIGIAN,ARTHUR G     4           FENWAY
# 21629      2377026     8259  CONNOLLY,CLIFFORD M     7  SCHROEDER PLAZA
# 2112       2345356     8260        CONWAY,JOHN A     9      FRANKLIN ST
# 2110       2343691     8260        CONWAY,JOHN A     9     RIVERBANK PL
# 56844      2452942     8260        CONWAY,JOHN A     9   POST OFFICE SQ
# 57972      2458577     8260        CONWAY,JOHN A     9   NEW CHARDON ST
# 57970      2459153     8260        CONWAY,JOHN A     9   POST OFFICE SQ
# 57980      2458388     8260        CONWAY,JOHN A     9   POST OFFICE SQ
# 57969      2462093     8260        CONWAY,JOHN A     9   POST OFFICE SQ
#
#         xStreet Detail\r\nDate  Start\r\nTime  End \r\nTime  Hours\r\nWorked  \
# 28182       NaN      5/11/2021           1630          2245              615
# 28564       NaN      5/14/2021           1630          2255              625
# 36828       NaN      6/11/2021           1630            12              742
# 35197       NaN      6/14/2021           1630          2245              615
# 36606       NaN      6/25/2021           1630          2355              725
# 37551       NaN      6/29/2021           1630          2342              712
# 38173       NaN      6/30/2021           1630           125              855
# 45370       NaN      8/11/2021           1630          2330              700
# 51734       NaN      9/21/2021           1630            18              748
# 52116       NaN      9/22/2021           1630            24              754
# 52389       NaN      9/24/2021           1630          2345              715
# 49157       NaN       9/7/2021           1630          2339              709
# 21629       NaN      4/15/2021            730          1600              830
# 2112        NaN      1/13/2021            700          1530              830
# 2110        NaN       1/3/2021            700          1600              900
# 56844       NaN      10/1/2021            730          1600              830
# 57972  CANAL ST     10/10/2021            700          1600              900
# 57970       NaN     10/12/2021            730          1600              830
# 57980       NaN     10/13/2021            730          1600              830
# 57969       NaN     10/14/2021            730          1600              830
#
#        Hours\r\nPaid Type  Customer No.  \
# 28182              8    S         92729
# 28564              8    S         92729
# 36828              8    S         92729
# 35197              8    S         92729
# 36606              8    S         92729
# 37551              8    S         92729
# 38173              9    S         92729
# 45370              8    S         92729
# 51734              8    S         92729
# 52116              8    S         92729
# 52389              8    S         92729
# 49157              8    S         92729
# 21629              9    C         99163
# 2112               9    C           384
# 2110               9    C         99078
# 56844              9    C          2838
# 57972              9    C          2838
# 57970              9    C          2838
# 57980              9    C          2838
# 57969              9    C          2838
#
#                                       Customer        Customer Address  \
# 28182     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 28564     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 36828     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 35197     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 36606     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 37551     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 38173     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 45370     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 51734     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 52116     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 52389     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 49157     RED SOX - BOSTON RED SOX ASSOCIATION             4 JERSEY ST
# 21629  BPD - BOSTON POLICE DEPARTMENT - B.F.S.       1 SCHROEDER PLAZA
# 2112             SHAWMUT DESIGN & CONSTRUCTION     560 HARRISON AVENUE
# 2110                       MACKAY CONSTRUCTION  197 BALLARDVALE STREET
# 56844                   MORIARTY, JOHN & ASSOC         3 CHURCH STREET
# 57972                   MORIARTY, JOHN & ASSOC         3 CHURCH STREET
# 57970                   MORIARTY, JOHN & ASSOC         3 CHURCH STREET
# 57980                   MORIARTY, JOHN & ASSOC         3 CHURCH STREET
# 57969                   MORIARTY, JOHN & ASSOC         3 CHURCH STREET
#
#         Customer Address 1 Customer Address 3 Customer_City Customer_State  \
# 28182  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 28564  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 36828  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 35197  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 36606  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 37551  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 38173  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 45370  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 51734  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 52116  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 52389  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 49157  ATTN: ACCTS PAYABLE                NaN        BOSTON             MA
# 21629                  NaN                NaN        BOSTON             MA
# 2112                   NaN                NaN       ROXBURY             MA
# 2110                   NaN                NaN    WILMINGTON             MA
# 56844                  NaN                NaN    WINCHESTER             MA
# 57972                  NaN                NaN    WINCHESTER             MA
# 57970                  NaN                NaN    WINCHESTER             MA
# 57980                  NaN                NaN    WINCHESTER             MA
# 57969                  NaN                NaN    WINCHESTER             MA
#
#       Customer_zip
# 28182        02215
# 28564        02215
# 36828        02215
# 35197        02215
# 36606        02215
# 37551        02215
# 38173        02215
# 45370        02215
# 51734        02215
# 52116        02215
# 52389        02215
# 49157        02215
# 21629        02120
# 2112         02118
# 2110         01887
# 56844        01890
# 57972        01890
# 57970        01890
# 57980        01890
# 57969        01890

# %% [markdown]
# ### Difference between hours worked and hours paid
# ### total number of hours worked
# ### Any pattern? time of year, location, weekdays/weekends,

# %%
temp_overtime21['count'] = temp_overtime21.groupby('Emp. ID').count().iloc[:, 0]

# %%
print(earnings21.columns)
# Out:
# Index(['NAME', 'DEPARTMENT_NAME', 'TITLE', 'REGULAR', 'RETRO', 'OTHER',
#        'OVERTIME', 'INJURED', 'DETAIL', 'QUINN_EDUCATION', 'TOTAL_ GROSS',
#        'POSTAL'],
#       dtype='object')

# %% [markdown]
# ## Check overtime pay dist
# ### 'str' and 'float' was mixed in 'OVERTIME'

# %%
import locale
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' ) 

temp_earnings21 = earnings21.copy()

def to_num(x):
    if isinstance(x, str):
        return float(x.replace(',', ''))
    else: 
        return x

temp_earnings21['OVERTIME_int'] = temp_earnings21['OVERTIME'].apply(to_num)

plt.hist(temp_earnings21['OVERTIME_int'])
plt.title('Dist of overtime pay')
# Out:
# Text(0.5, 1.0, 'Dist of overtime pay')

# %% [markdown]
# ### TOO many titles...

# %%
print(set(temp_earnings21['TITLE']))
len(set(temp_earnings21['TITLE']))
# Out:
# {'ILL & Research Svcs Librarian', 'Maint Mech(LightSvcRpr)(Pwd)##', 'Veterinary Medical Director', 'Sen Sup School Bldgs Alt&Rep', 'Fire Fighter (InctComndSp) DFC', 'Traffic Signal Supv', 'Prin Clerk & Typist', 'Community Relations Spec(P&R)', 'Sr Data Proc Sys Anl (BTD)', 'Dir-EconomicDevelopmentPolicy', 'AssocDir,BPDOfficeofReas&Devel', 'Commissioner (P&R)', 'CommHistory&DigitizationSpcls', 'Dog Offcr(Sr Animal Cntl Ofcr)', 'Commissioner Elderly Affairs', 'Sr Legal Asst', 'Strategic Manager', 'HR Customer Service Rep', 'Asst City Registrar', 'HdOfBibliographicServMetrBLNet', 'Young Adults Librarian I', 'Exec Sec (P&R) Cementaries', 'Principal Fellow', 'Exec Sec', 'Spec Library Asst V', 'Dir of Outreach & Engagement', 'Admin Asst (Igr)', 'Housing Development Offcr', 'BusinessOperationsDataAnalyst', 'Reader & Info Librarian I', 'Prin Civil Engineer', 'Technician (B)', 'Dog Offr(AnimalControlOffcr)##', 'Dir Human Resources (Parks)', 'Senior Director (BASAS 12B)', 'FF (FPDInspLevl1Certfctn)-ADR', 'Sen Prog Dir 12 (non-ac)', 'Head Storekeeper', 'Collection Agent BFD FirePreve', 'Park Ranger III', 'Yth Educational Outreach Coord', 'Hot Line Worker', 'Trans Program Planner III', 'FF (Asst Dive Mast)', 'RegionalEmergencyMgmntPlanner', 'Cafeteria Manager 10', 'Programs & Comm Outreach Libr', 'Exec Asst Commissioner', 'Operations Assignment Coor', 'FF (Asst Supn Maint)', 'Sr Finance Manager', 'Developer(C)', 'Program Supervisor', 'Sr Research Analyst (Asn)', 'Recreation Rscr Dvlpmnt Mangr', 'EmrgMgtTraining&ExerciseCoord', 'Asst Dir Housing Inspection', 'FIU Supervisor Photo Unit', 'Mech Equip Repairprs (PM)', 'Prin Civil Eng (Fss)##', 'First AsstCorporationCounsels', 'Staff Asst (Administration)', 'Grant Manager', 'Sen Cust C', 'Lead Satellite Attendant A', 'Chief of Safety Serv', 'Supn-Sanitation', 'Head Clerk & Secretary', 'Financial Analyst', 'Director Of Instruction', 'Staff Asst (Pt)', 'Police Captain', 'Behavioral Health Director', 'Sr Data Proc Sys Anl I', 'Sen Specialist (C)', 'Sr Investigator', 'Sr Review Architect (PFD)', 'Sr. Disability Representative', 'Teacher I', 'Archaeologist (Envrnmntl Dept)', 'Head Admin Clerk-32', 'Service Writer', 'Manager NonAcad C', 'Chief Engineer (P&R)', 'Prin Accountant', 'Asst Dir (DND)', 'Program Administrator', 'Communication Spec', 'Archivist', 'Greenhouse Gardener', 'Substitute Nurse HE', 'Exec Asst', 'Assoc Electrical Engineer', 'Sr General Tree Maintenance', 'Manager,Training & Development', 'Prin Clerk/School Sec 23', 'Police Offc Harborboat 3$8', 'Sr Outrch & Engmnt Coord (BCYF', 'Traffic Signal Repairprs##', 'Wkg Frprs Painter', 'Program Director (BASAS 11B)', 'Asst Buyer', 'Area Supv of Street Operations', 'Dep Dir', 'Research Specialist', 'Sr Personnel Analyst', 'Supv Graphic Arts Svc (BPD)', 'Hvy Mtr Equip Repairpr Class I', 'Sr Data Proc Sys Anl (ASD/DPU)', 'Talent Acquisition Specialist', 'Asst Bldg Commissioner', 'Chief of Adult Library Servcs', 'Commissioner (BFD)', 'Chief Of Planning', 'Asst Civil Engineer', 'Admin Asst (PFD)', 'Office Manager(Asn)', 'Chief of Civic Engagement', 'Childrens Librarian II', 'FF (Constituent Liaison Off)', 'Fire Captain Admn-Advance Tech', "BPS Worker's Comp Job Class", 'Utility Inspector', 'Coordinator (C)', 'Contract Manager (PFD)', 'Exec Sec  (P&R Comm Office)', 'Supv-Sanitation (Pwd)', 'DeputyChiefHumanCapitalOff(E)', 'Chief of Human Services', 'Mask Repair Specialist', 'Dir of Fleet Management', 'Sub Nurse-Retiree', 'STC(SecuringtheCity)ProgDirBPD', 'Chief of Environment & Energy', 'FF(SOCEquip&LogMgr)-Technician', 'Highway Maint Inspector##', 'Mech Equip Repairprs Foreprs', 'Spec Asst I', 'Exec Asst(Office Manager)', 'Chief Power Plant Eng', 'Digital Imaging Production Ast', 'Dir-Marketing', 'Cash Management Auditor', 'Unit Leader (C)', 'Sr Radio Communications Tech', 'Criminalist II', '121A Manager, BOR', 'HRIS Specialist', 'Dir Bldg & Structure Div', 'Dep Fire Chief', 'Asst Keeper Of Prints', 'Emrgncy Comm Spec Police Dispa', 'Corporate  ...
# 1507

# %% [markdown]
# ## Check overtime frequency by person

# %%
overtime21.columns
# Out:
# Index(['Tracking_No', 'Emp. ID', 'Employee', 'Rank', 'Street', 'xStreet',
#        'Detail\r\nDate', 'Start\r\nTime', 'End \r\nTime', 'Hours\r\nWorked',
#        'Hours\r\nPaid', 'Type', 'Customer No.', 'Customer', 'Customer Address',
#        'Customer Address 1', 'Customer Address 3', 'Customer_City',
#        'Customer_State', 'Customer_zip'],
#       dtype='object')

# %%
overtime21['OVERTIME_FREQ'] = overtime21.groupby(['Emp. ID'])['Emp. ID'].count()
plt.hist(overtime21['OVERTIME_FREQ'])
plt.title('Dist of overtime frequency')
# Out:
# Text(0.5, 1.0, 'Dist of overtime frequency')

# %%
# set(overtime21['RANK'])

print(set(overtime21['Rank']))

figure, axis = plt.subplots(4, 2) 

# for i in range(3,10): 
#     try:
# #         axis[0,0].plt.hist(overtime21[overtime21['Rank']==i]['OVERTIME_FREQ'])
#         plt.hist(overtime21[overtime21['Rank']==i]['OVERTIME_FREQ'])
#         plt.title(f'Rank {i} Dist of overtime frequency')
#     except:
#         print(f"Rank {i} data is not working")
        
# plt.show()
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
plt.hist(overtime21[overtime21['Rank']==3]['OVERTIME_FREQ'])
# Out:
# (array([1., 3., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 10. ,  23.1,  36.2,  49.3,  62.4,  75.5,  88.6, 101.7, 114.8,
#         127.9, 141. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Rank==4 data isn't working

# %%
plt.hist(overtime21[overtime21['Rank']==5]['OVERTIME_FREQ'])
# Out:
# (array([3., 3., 0., 2., 0., 0., 0., 0., 0., 1.]),
#  array([  1. ,  16.3,  31.6,  46.9,  62.2,  77.5,  92.8, 108.1, 123.4,
#         138.7, 154. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(overtime21[overtime21['Rank']==6]['OVERTIME_FREQ'])
# Out:
# (array([3., 2., 0., 1., 0., 0., 0., 0., 0., 1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(overtime21[overtime21['Rank']==7]['OVERTIME_FREQ'])
# Out:
# (array([12.,  6.,  2.,  1.,  1.,  1.,  2.,  1.,  2.,  2.]),
#  array([  1. ,  22.4,  43.8,  65.2,  86.6, 108. , 129.4, 150.8, 172.2,
#         193.6, 215. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(overtime21[overtime21['Rank']==8]['OVERTIME_FREQ'])
# Out:
# (array([12.,  4.,  1.,  2.,  4.,  0.,  1.,  0.,  2.,  2.]),
#  array([  1.,  20.,  39.,  58.,  77.,  96., 115., 134., 153., 172., 191.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(overtime21[overtime21['Rank']==9]['OVERTIME_FREQ'])
# Out:
# (array([212.,  64.,  49.,  29.,  26.,  14.,   3.,   7.,   3.,   2.]),
#  array([  1. ,  34.8,  68.6, 102.4, 136.2, 170. , 203.8, 237.6, 271.4,
#         305.2, 339. ]),
#  <BarContainer object of 10 artists>)
