# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def read_csv_file(filepath):
    df = pd.read_csv(filepath)
    return df

filepath = 'earning-data.csv'
df = read_csv_file(filepath)
df.describe()


#Conversions and cleanups
df['INJURED'] = df['INJURED'].str.replace(',', '').astype(float)
df['TOTAL_ GROSS'] = df['TOTAL_ GROSS'].str.replace(',', '').astype(float)
df['OVERTIME'] = df['OVERTIME'].str.replace(',', '').astype(float)
df['REGULAR'] = df['REGULAR'].str.replace(',', '').astype(float)

df['OT_to_Regular_Ratio'] = df['OVERTIME'] / df['REGULAR']


#filter department by boston police department
df_police = df[df['DEPARTMENT_NAME'] == 'Boston Police Department']
df_police.head(100)
# Out:
#                    NAME           DEPARTMENT_NAME                    TITLE  \
# 0        Gavin,Donna M.  Boston Police Department  Police Lieutenant (Det)
# 3      Demesmin,Stanley  Boston Police Department  Police Lieutenant (Det)
# 4          Smith,Sean P  Boston Police Department        Police Lieutenant
# 5    McCormick,Kelley J  Boston Police Department           Police Captain
# 6        Long,Gregory P  Boston Police Department            Supn-In Chief
# ..                  ...                       ...                      ...
# 132      Boyle,Joseph P  Boston Police Department       Police Captain/DDC
# 133        Pratt,Thomas  Boston Police Department    Police Sergeant (Det)
# 134    Yalmokas,Kevin J  Boston Police Department          Police Sergeant
# 135       Jones,Craig D  Boston Police Department           Police Officer
# 136  Driscoll,Richard J  Boston Police Department       Police Lieut (Det)
#
#        REGULAR RETRO         OTHER   OVERTIME   INJURED     DETAIL  \
# 0     53226.90   NaN  1,045,845.44     463.52       NaN        NaN
# 3    145775.26   NaN     13,932.92  196515.25       NaN  11,880.00
# 4    142535.62   NaN     18,827.45  142692.38       NaN  46,365.00
# 5    147690.64   NaN      7,452.73   83593.06  16410.06  78,060.00
# 6    290703.31   NaN     30,244.46        NaN       NaN        NaN
# ..         ...   ...           ...        ...       ...        ...
# 132  164500.82   NaN     20,806.84   43727.38       NaN        NaN
# 133  132392.79   NaN     18,872.19   86662.89       NaN        NaN
# 134  130263.05   NaN     11,969.32   93767.68       NaN   8,904.00
# 135  108038.52   NaN     10,583.21  144457.87       NaN   6,302.00
# 136  143478.61   NaN     20,788.61   69159.65       NaN        NaN
#
#     QUINN_EDUCATION  TOTAL_ GROSS POSTAL  OT_to_Regular_Ratio
# 0         12,812.39    1112348.25  02186             0.008708
# 3         29,155.26     397258.69  02052             1.348070
# 4         35,633.88     386054.33  02186             1.001100
# 5         41,025.08     374231.57  02476             0.566001
# 6         52,180.57     373128.34  02021                  NaN
# ..              ...           ...    ...                  ...
# 132       41,125.36     270160.40  02186             0.265819
# 133       31,906.88     269834.75  02127             0.654589
# 134       24,795.84     269699.89  02668             0.719833
# 135             NaN     269381.60  02324             1.337096
# 136       35,420.18     268847.05  02122             0.482021
#
# [100 rows x 13 columns]

# %%
#sort police earning data by overtime descending
df_police.sort_values(by=['OVERTIME'], ascending=False).head(100)
# Out:
#                     NAME           DEPARTMENT_NAME  \
# 3       Demesmin,Stanley  Boston Police Department
# 14     Barrett,Thomas E.  Boston Police Department
# 31         Downey,Paul J  Boston Police Department
# 111        Acosta,Jose L  Boston Police Department
# 19        Johnson,Rick E  Boston Police Department
# ..                   ...                       ...
# 570       Doiron,James M  Boston Police Department
# 821  DeLaCruz,Bienvenido  Boston Police Department
# 153     Ciccolo,Steven M  Boston Police Department
# 681         Wallace,Sean  Boston Police Department
# 281        Conway,John D  Boston Police Department
#
#                            TITLE    REGULAR RETRO      OTHER   OVERTIME  \
# 3        Police Lieutenant (Det)  145775.26   NaN  13,932.92  196515.25
# 14         Police Sergeant (Det)  130930.12   NaN  16,723.95  163494.70
# 31               Police Sergeant  136588.74   NaN   3,187.71  163269.38
# 111               Police Officer  109502.02   NaN  10,665.06  151608.89
# 19         Police Sergeant (Det)  127626.76   NaN  19,246.67  150658.84
# ..                           ...        ...   ...        ...        ...
# 570               Police Officer  100279.56   NaN   5,347.91   90522.90
# 821               Police Officer  104614.25   NaN     800.00   90374.08
# 153            Police Lieutenant  142535.62   NaN     850.00   90034.63
# 681             Police Detective  102319.02   NaN     800.00   90032.99
# 281  Police Sergeant/Mobile Oper  120825.20   NaN   4,333.25   89354.41
#
#      INJURED     DETAIL QUINN_EDUCATION  TOTAL_ GROSS POSTAL  \
# 3        NaN  11,880.00       29,155.26     397258.69  02052
# 14       NaN        NaN       32,732.72     343881.49  02132
# 31       NaN  12,402.00             NaN     315447.83  02132
# 111      NaN   5,152.00             NaN     276927.97  01960
# 19       NaN     424.00       31,906.88     329863.15  02072
# ..       ...        ...             ...           ...    ...
# 570      NaN   6,624.00       10,028.16     212802.53  02359
# 821      NaN   1,472.00             NaN     197260.33  02170
# 153      NaN   1,320.00       28,507.02     263247.27  02186
# 681      NaN   2,024.00        9,661.18     204837.19  02127
# 281      NaN        NaN       24,165.22     238678.08  02359
#
#      OT_to_Regular_Ratio
# 3               1.348070
# 14              1.248717
# 31              1.195336
# 111             1.384531
# 19              1.180464
# ..                   ...
# 570             0.902705
# 821             0.863879
# 153             0.631664
# 681             0.879924
# 281             0.739535
#
# [100 rows x 13 columns]

# %%
total_injury_pay = df_police['INJURED'].sum()

# %%
percentage_injury_pay = (total_injury_pay / df_police['TOTAL_ GROSS'].sum()) * 100
officers_with_injury_pay = df_police[df_police['INJURED'] > 0].shape[0]

# Calculate the percentage of officers who took injury pay
percentage_officers_injury_pay = (officers_with_injury_pay / df_police.shape[0]) * 100

# Print the result
print(f"Percentage of BPD Officers Who Took Injury Pay: {percentage_officers_injury_pay:.2f}%")

print(f"Total Injury Pay for BPD Officers: ${total_injury_pay:,.2f}")
print(f"Percentage of Total Gross Pay from Injury Pay: {percentage_injury_pay:.2f}%")
# Out:
# Percentage of BPD Officers Who Took Injury Pay: 15.07%
# Total Injury Pay for BPD Officers: $23,628,467.04
# Percentage of Total Gross Pay from Injury Pay: 5.82%

# %%
officers_with_overtime_pay = df_police[df_police['OVERTIME'] > 0].shape[0]

# Calculate the percentage of officers who took overtime pay
percentage_officers_overtime_pay = (officers_with_overtime_pay / df_police.shape[0]) * 100

# Print the result
print(f"Percentage of BPD Officers Who Took Overtime Pay: {percentage_officers_overtime_pay:.2f}%")

top_ot_ratio_officers = df_police.sort_values(by='OT_to_Regular_Ratio', ascending=False).head(10)
print(top_ot_ratio_officers[['NAME', 'REGULAR', 'OVERTIME', 'OT_to_Regular_Ratio']])

# Set the style for the plot
sns.set_style("whitegrid")

# Plot the distribution of the overtime-to-regular-pay ratios
plt.figure(figsize=(12, 6))
sns.boxplot(df_police['OT_to_Regular_Ratio'], orient='h')
plt.title('Distribution of Overtime-to-Regular-Pay Ratios for BPD Officers')
plt.xlabel('OT-to-Regular Pay Ratio')
plt.show()
# Out:
# Percentage of BPD Officers Who Took Overtime Pay: 79.77%
#                     NAME    REGULAR   OVERTIME  OT_to_Regular_Ratio
# 20438   Stewart,Greta E.    1977.92    4785.93             2.419678
# 11518  Woodley,Lorenzo I   11775.11   21638.24             1.837625
# 1846     Webster,Geneese   65294.61   93654.82             1.434342
# 111        Acosta,Jose L  109502.02  151608.89             1.384531
# 3       Demesmin,Stanley  145775.26  196515.25             1.348070
# 135        Jones,Craig D  108038.52  144457.87             1.337096
# 203    Christie,Albert C  109502.02  141222.99             1.289684
# 14     Barrett,Thomas E.  130930.12  163494.70             1.248717
# 387    Cornelius,Devon M   92637.86  112645.22             1.215974
# 260     Shikoluk,Michael   99922.46  121258.11             1.213522

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='TOTAL_ GROSS', y='OVERTIME', data=df_police, scatter_kws={'alpha':0.5})
plt.title('Correlation between Total Salary and Overtime Hours of Police Officers')
plt.xlabel('Total Salary')
plt.ylabel('Overtime Hours')
plt.show()


correlation = df_police['TOTAL_ GROSS'].corr(df_police['OVERTIME'])

print(f"The correlation coefficient between total salary and overtime hours is: {correlation}")
# Out:
# The correlation coefficient between total salary and overtime hours is: 0.740993802130584

# %%
top_percentage = 0.10
num_officers = len(df_police)
threshold_for_top_overtime = df_police['OVERTIME'].nlargest(int(num_officers * top_percentage)).min()
threshold_for_top_salaries = df_police['TOTAL_ GROSS'].nlargest(int(num_officers * top_percentage)).min()

# Identify the two groups
frequent_overtime_users = df_police[df_police['OVERTIME'] >= threshold_for_top_overtime]
high_salary_officers = df_police[df_police['TOTAL_ GROSS'] >= threshold_for_top_salaries]

# Find overlap
overlap = pd.merge(frequent_overtime_users, high_salary_officers, how='inner', on=['NAME', 'DEPARTMENT_NAME', 'TITLE', 'TOTAL_ GROSS', 'OVERTIME'])

# Output the result
num_overlap = len(overlap)
print(f"Number of officers in both high overtime and high salary categories: {num_overlap}")


plt.figure(figsize=(12, 8))
plt.scatter(df_police['OVERTIME'], df_police['TOTAL_ GROSS'], alpha=0.5, label='All Officers')

# Highlight areas
plt.axvline(x=threshold_for_top_overtime, color='r', linestyle='--', label='Top 10% Overtime Pay')
plt.axhline(y=threshold_for_top_salaries, color='b', linestyle='--', label='Top 10% Salary')

# Highlight overlapping officers
overlap = df_police[(df_police['OVERTIME'] >= threshold_for_top_overtime) & (df_police['TOTAL_ GROSS'] >= threshold_for_top_salaries)]
plt.scatter(overlap['OVERTIME'], overlap['TOTAL_ GROSS'], color='green', label='High Overtime & Salary')
 
# Labeling
plt.title('Overlap of High Overtime and High Salary Officers')
plt.xlabel('Overtime Pay')
plt.ylabel('Total Salary')
plt.legend()
plt.show()
# Out:
# Number of officers in both high overtime and high salary categories: 190
