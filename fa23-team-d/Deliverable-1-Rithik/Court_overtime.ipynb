# %% [markdown]
# ## Calculating overpaid overtime hours for years ranging from [2012,2022]

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'Court_Overtime_2021_-_2022_ytd.xlsx'
xls = pd.ExcelFile(file_path)

sheet_names = xls.sheet_names
print("Sheet Names:", sheet_names)

# Single workbook with multiple sheets
df2 = pd.read_excel(xls, '2021')
df = pd.read_excel(xls, '2022 ytd')
# Out:
# Sheet Names: ['2021', '2022 ytd']

# %% [markdown]
# ### Court overpaid overtime hours for 2022

# %%
df.head()
# Out:
#        ID                   NAME    RANK                ASSIGNED_DESC  \
# 0  153140      Langton,Kylie Ann     Ptl              B-2   DCU SQUAD
# 1   11687      Gallagher,William  SgtDet       LICENSED PREMISES UNIT
# 2  131218      Smerz,Christopher     Ptl  YOUTH VIOLENCE STRIKE FORCE
# 3   10744      Williams,David C.     Det       DOMESTIC VIOLENCE UNIT
# 4  153100  Flaherty,John Michael     Ptl                  DISTRICT 04
#
#                   CHARGED_DESC     OTDATE  OTCODE           DESCRIPTION  \
# 0              B-2   DCU SQUAD 2022-01-03     280           COURT:TRIAL
# 1       LICENSED PREMISES UNIT 2022-01-03     281  COURT:CLERK MAG. HRG
# 2  YOUTH VIOLENCE STRIKE FORCE 2022-01-03     286      COURT:CASE PREP.
# 3       DOMESTIC VIOLENCE UNIT 2022-01-03     281  COURT:CLERK MAG. HRG
# 4                  DISTRICT 04 2022-01-03     281  COURT:CLERK MAG. HRG
#
#    STARTTIME  ENDTIME  WRKDHRS  OTHOURS
# 0        830      900     0.50      4.0
# 1        900      930     0.50      4.0
# 2       1000     1030     0.50      4.0
# 3       1015     1100     0.75      4.0
# 4        900      945     0.75      4.0

# %%
df['Overpaid_Hours'] = df['OTHOURS'] - df['WRKDHRS']
overpaid_2022 = df['Overpaid_Hours'].sum()
print("Total overpaid hours for the year 2022:", overpaid_2022)
# Out:
# Total overpaid hours for the year 2022: 37165.5

# %% [markdown]
# ### Court overpaid overtime hours for 2021

# %%
df2.head()
# Out:
#        ID              NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0  153088       Chen,Steven  Ptl       DISTRICT 01       DISTRICT 01
# 1   53603     Gero,Jarrod A  Det  B-2   DETECTIVES  B-2   DETECTIVES
# 2   11716  McCarthy,Peter L  Det  B-3   DETECTIVES  B-3   DETECTIVES
# 3  157666     Mejia,Karen Y  Ptl       DISTRICT 01       DISTRICT 01
# 4   12045  Merricks,Kirk D.  Ptl       DISTRICT 01       DISTRICT 01
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2021-01-05     281  COURT:CLERK MAG. HRG        900      930     0.50
# 1 2021-01-06     283    COURT:MOTIONS HRG.       1130     1230     1.00
# 2 2021-01-04     286      COURT:CASE PREP.       1600     1730     1.50
# 3 2021-01-04     281  COURT:CLERK MAG. HRG        900      930     0.50
# 4 2021-01-05     281  COURT:CLERK MAG. HRG        900      915     0.25
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
df2['Overpaid_Hours'] = df2['OTHOURS'] - df2['WRKDHRS']
overpaid_2021 = df2['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2021:", overpaid_2021)
# Out:
# Total overpaid hours for year 2021: 29836.0

# %% [markdown]
# ### Court overpaid overtime hours for years 2018-2020

# %%
import pandas as pd

file_path = 'Court_Overtime_2018_-_2020.xlsx'
xls = pd.ExcelFile(file_path)

# Single workbook with multiple sheets
df1 = pd.read_excel(xls, '2018')
df2 = pd.read_excel(xls, '2019')
df3 = pd.read_excel(xls, '2020')

# %% [markdown]
# #### 2020

# %%
df3.head()
# Out:
#          ID                NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0   11120.0  Moriarty,Richard G  Det  C-6   DETECTIVES  C-6   DETECTIVES
# 1  144460.0   Linsky,Benjamin N  Ptl       DISTRICT 02       DISTRICT 02
# 2  135932.0        McBrien,Marc  Ptl       DISTRICT 02       DISTRICT 02
# 3   95177.0    O'Rourke,Michael  Ptl       DISTRICT 02       DISTRICT 02
# 4   93797.0   Fogarty,Matthew J  Det  B-3   DETECTIVES  B-3   DETECTIVES
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2020-01-02     283    COURT:MOTIONS HRG.        930     1000      0.5
# 1 2020-01-03     281  COURT:CLERK MAG. HRG        900      930      0.5
# 2 2020-01-03     280           COURT:TRIAL        830      900      0.5
# 3 2020-01-03     281  COURT:CLERK MAG. HRG        900     1000      1.0
# 4 2020-01-03     282  COURT:PRETRIAL CONF.        900     1000      1.0
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
df3['Overpaid_Hours'] = df3['OTHOURS'] - df3['WRKDHRS']
overpaid_2020 = df3['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2020:", overpaid_2020)
# Out:
# Total overpaid hours for year 2020: 23405.75

# %% [markdown]
# #### 2019

# %%
df2.head()
# Out:
#        ID                NAME    RANK    ASSIGNED_DESC     CHARGED_DESC  \
# 0  108602        Pokrant,Drew     Ptl      DISTRICT 18      DISTRICT 18
# 1   96731   Barrett,Thomas E.  SgtDet    HOMICIDE UNIT    HOMICIDE UNIT
# 2  103784  Samaras,William J.     Det  E-5   DCU SQUAD  E-5   DCU SQUAD
# 3   10597     Troy,Anthony E.  SgtDet  E-5   DCU SQUAD  E-5   DCU SQUAD
# 4   10652     Keenan,Donald F  SgtDet  D-4   DCU SQUAD  D-4   DCU SQUAD
#
#       OTDATE  OTCODE         DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  OTHOURS
# 0 2019-01-02     288   PROBATION HEARING        830     1100      2.5      4.0
# 1 2019-01-02     283  COURT:MOTIONS HRG.        900     1330      4.5      4.5
# 2 2019-01-02     283  COURT:MOTIONS HRG.        900     1030      1.5      4.0
# 3 2019-01-02     283  COURT:MOTIONS HRG.        900     1030      1.5      4.0
# 4 2019-01-04     280         COURT:TRIAL        830      930      1.0      4.0

# %%
df2['Overpaid_Hours'] = df2['OTHOURS'] - df2['WRKDHRS']
overpaid_2019 = df2['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2019:", overpaid_2019)
# Out:
# Total overpaid hours for year 2019: 60654.25

# %% [markdown]
# #### 2018

# %%
df1.head()
# Out:
#        ID                 NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0    9033    O'Brien,Stephen T  Det  B-3   DETECTIVES  B-3   DETECTIVES
# 1   50308  O'Toole,John Edward  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
# 2  102349        Monahan,Keith  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
# 3   11575       Adams,Daniel J  Det    E-18 DCU SQUAD    E-18 DCU SQUAD
# 4  103759        Green,W. Scot  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2018-01-02     281  COURT:CLERK MAG. HRG       1000     1100     1.00
# 1 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 2 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 3 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 4 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
df1['Overpaid_Hours'] = df1['OTHOURS'] - df1['WRKDHRS']
overpaid_2018 = df1['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2018:", overpaid_2018)
# Out:
# Total overpaid hours for year 2018: 57864.5

# %% [markdown]
# ### Court overpaid overtime hours for years 2015-2017

# %%
file_path = 'Court_Overtime_2015_-_2017.xlsx'
xls = pd.ExcelFile(file_path)

# Single workbook with multiple sheets
df1 = pd.read_excel(xls, '2015')
df2 = pd.read_excel(xls, '2016')
df3 = pd.read_excel(xls, '2017')

# %% [markdown]
# #### 2017

# %%
df3.head()
# Out:
#          ID                NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0   11120.0  Moriarty,Richard G  Det  C-6   DETECTIVES  C-6   DETECTIVES
# 1  144460.0   Linsky,Benjamin N  Ptl       DISTRICT 02       DISTRICT 02
# 2  135932.0        McBrien,Marc  Ptl       DISTRICT 02       DISTRICT 02
# 3   95177.0    O'Rourke,Michael  Ptl       DISTRICT 02       DISTRICT 02
# 4   93797.0   Fogarty,Matthew J  Det  B-3   DETECTIVES  B-3   DETECTIVES
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2020-01-02     283    COURT:MOTIONS HRG.        930     1000      0.5
# 1 2020-01-03     281  COURT:CLERK MAG. HRG        900      930      0.5
# 2 2020-01-03     280           COURT:TRIAL        830      900      0.5
# 3 2020-01-03     281  COURT:CLERK MAG. HRG        900     1000      1.0
# 4 2020-01-03     282  COURT:PRETRIAL CONF.        900     1000      1.0
#
#    OTHOURS  Overpaid_Hours
# 0      4.0             3.5
# 1      4.0             3.5
# 2      4.0             3.5
# 3      4.0             3.0
# 4      4.0             3.0

# %%
df3['Overpaid_Hours'] = df3['OTHOURS'] - df3['WRKDHRS']
overpaid_2017 = df3['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2017:", overpaid_2017)
# Out:
# Total overpaid hours for year 2017: 23405.75

# %% [markdown]
# #### 2016

# %%
df2.head()
# Out:
#        ID                NAME    RANK    ASSIGNED_DESC     CHARGED_DESC  \
# 0  108602        Pokrant,Drew     Ptl      DISTRICT 18      DISTRICT 18
# 1   96731   Barrett,Thomas E.  SgtDet    HOMICIDE UNIT    HOMICIDE UNIT
# 2  103784  Samaras,William J.     Det  E-5   DCU SQUAD  E-5   DCU SQUAD
# 3   10597     Troy,Anthony E.  SgtDet  E-5   DCU SQUAD  E-5   DCU SQUAD
# 4   10652     Keenan,Donald F  SgtDet  D-4   DCU SQUAD  D-4   DCU SQUAD
#
#       OTDATE  OTCODE         DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  OTHOURS
# 0 2019-01-02     288   PROBATION HEARING        830     1100      2.5      4.0
# 1 2019-01-02     283  COURT:MOTIONS HRG.        900     1330      4.5      4.5
# 2 2019-01-02     283  COURT:MOTIONS HRG.        900     1030      1.5      4.0
# 3 2019-01-02     283  COURT:MOTIONS HRG.        900     1030      1.5      4.0
# 4 2019-01-04     280         COURT:TRIAL        830      930      1.0      4.0

# %%
df2['Overpaid_Hours'] = df2['OTHOURS'] - df2['WRKDHRS']
overpaid_2016 = df2['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2016:", overpaid_2016)
# Out:
# Total overpaid hours for year 2016: 60654.25

# %% [markdown]
# #### 2015

# %%
df1.head()
# Out:
#        ID                 NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0    9033    O'Brien,Stephen T  Det  B-3   DETECTIVES  B-3   DETECTIVES
# 1   50308  O'Toole,John Edward  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
# 2  102349        Monahan,Keith  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
# 3   11575       Adams,Daniel J  Det    E-18 DCU SQUAD    E-18 DCU SQUAD
# 4  103759        Green,W. Scot  Ptl    E-18 DCU SQUAD    E-18 DCU SQUAD
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2018-01-02     281  COURT:CLERK MAG. HRG       1000     1100     1.00
# 1 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 2 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 3 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
# 4 2018-01-03     283    COURT:MOTIONS HRG.        830     1015     1.75
#
#    OTHOURS  Overpaid_Hours
# 0      4.0            3.00
# 1      4.0            2.25
# 2      4.0            2.25
# 3      4.0            2.25
# 4      4.0            2.25

# %%
df1['Overpaid_Hours'] = df1['OTHOURS'] - df1['WRKDHRS']
overpaid_2015 = df1['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2015:", overpaid_2015)
# Out:
# Total overpaid hours for year 2015: 65135.75

# %% [markdown]
# ### Court overpaid overtime hours for years 2012-2014

# %%
file_path = 'Court_Overtime_2012_-_2014.xlsx'
xls = pd.ExcelFile(file_path)

# Single workbook with multiple sheets
df1 = pd.read_excel(xls, '2012')
df2 = pd.read_excel(xls, '2013')
df3 = pd.read_excel(xls, '2014')

# %% [markdown]
# #### 2014

# %%
df3.head()
# Out:
#        ID                  NAME RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0  116168            Gomes,Jose  Ptl       DISTRICT 03       DISTRICT 03
# 1   10439        Painten,Paul A  Det  B-2   DETECTIVES  B-2   DETECTIVES
# 2    9282      Fontanez,Peter N  Ptl   A-7   DCU SQUAD   A-7   DCU SQUAD
# 3   11715       McCarthy,John A  Det   A-7   DCU SQUAD   A-7   DCU SQUAD
# 4   95168  Byrne,Patrick Edward  Ptl   A-1   DCU SQUAD   A-1   DCU SQUAD
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2014-01-02     280           COURT:TRIAL        900      930      0.5
# 1 2014-01-02     281  COURT:CLERK MAG. HRG        900     1000      1.0
# 2 2014-01-03     283    COURT:MOTIONS HRG.        830      930      1.0
# 3 2014-01-03     283    COURT:MOTIONS HRG.        830      930      1.0
# 4 2014-01-02     280           COURT:TRIAL        830     1000      1.5
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
df3['Overpaid_Hours'] = df3['OTHOURS'] - df3['WRKDHRS']
overpaid_2014 = df3['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2014:", overpaid_2014)
# Out:
# Total overpaid hours for year 2014: 63513.75

# %% [markdown]
# #### 2013

# %%
df2.head()
# Out:
#       ID                NAME    RANK     ASSIGNED_DESC      CHARGED_DESC  \
# 0   9588     Keeley,Thomas J     Det  D-4   DETECTIVES  D-4   DETECTIVES
# 1  10186  Parlon,William Leo     Det  D-4   DETECTIVES  D-4   DETECTIVES
# 2  10439      Painten,Paul A     Det  B-2   DETECTIVES  B-2   DETECTIVES
# 3  10305  Stratton,Michael J  SgtDet  B-2   DETECTIVES  B-2   DETECTIVES
# 4  10305  Stratton,Michael J  SgtDet  B-2   DETECTIVES  B-2   DETECTIVES
#
#       OTDATE  OTCODE           DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  \
# 0 2013-01-02     281  COURT:CLERK MAG. HRG        830     1000     1.50
# 1 2013-01-02     281  COURT:CLERK MAG. HRG        830      930     1.00
# 2 2013-01-02     281  COURT:CLERK MAG. HRG        830      915     0.75
# 3 2013-01-02     286      COURT:CASE PREP.       1430     1600     1.50
# 4 2013-01-03     280           COURT:TRIAL       1000     1100     1.00
#
#    OTHOURS
# 0      4.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      4.0

# %%
df2['Overpaid_Hours'] = df2['OTHOURS'] - df2['WRKDHRS']
overpaid_2013 = df2['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2013:", overpaid_2013)
# Out:
# Total overpaid hours for year 2013: 66088.0

# %% [markdown]
# #### 2012

# %%
df1.head()
# Out:
#        ID                NAME RANK ASSIGNED_DESC CHARGED_DESC     OTDATE  \
# 0  103591  Bissonnette,Philip  Ptl   DISTRICT 03  DISTRICT 03 2012-01-04
# 1  103782     Rooney,Kevin D.  Ptl   DISTRICT 03  DISTRICT 03 2012-01-03
# 2   11045        Ruiz,Jose A.  Ptl   DISTRICT 03  DISTRICT 03 2012-01-03
# 3    9726     Doherty,Henry J  Ptl   DISTRICT 03  DISTRICT 03 2012-01-04
# 4   11395     Boylan,Edward J  Ptl   DISTRICT 11  DISTRICT 11 2012-01-03
#
#    OTCODE         DESCRIPTION  STARTTIME  ENDTIME  WRKDHRS  OTHOURS
# 0     280         COURT:TRIAL        900      915     0.25      4.0
# 1     280         COURT:TRIAL        915      930     0.25      4.0
# 2     283  COURT:MOTIONS HRG.        830     1000     1.50      4.0
# 3     280         COURT:TRIAL        830      915     0.75      4.0
# 4     280         COURT:TRIAL        830     1000     1.50      4.0

# %%
df1['Overpaid_Hours'] = df1['OTHOURS'] - df1['WRKDHRS']
overpaid_2012 = df1['Overpaid_Hours'].sum()
print("Total overpaid hours for year 2012:", overpaid_2012)
# Out:
# Total overpaid hours for year 2012: 74320.25

# %% [markdown]
# ## Now we have the overpaid hours for the years ranging from 2012 to 2022, let's visualize how overtime for the court appearances changed year-over-year

# %%
# Extract the years and overpaid hours
years = list(range(2012, 2023))
overpaid = [overpaid_2012, overpaid_2013, overpaid_2014, overpaid_2015, overpaid_2016, overpaid_2017, overpaid_2018, overpaid_2019, overpaid_2020, overpaid_2021, overpaid_2022]

# Create a line chart
plt.figure(figsize=(10, 6))
plt.plot(years, overpaid, marker='o', linestyle='-')
plt.title('Overpaid Hours Over the Years (2012-2022)')
plt.xlabel('Year')
plt.ylabel('Overpaid Hours')
plt.grid(True)
plt.xticks(years)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(years, overpaid)
plt.title('Overpaid Hours Over the Years (2012-2022)')
plt.xlabel('Year')
plt.ylabel('Overpaid Hours')
plt.grid(axis='y')
plt.xticks(years)
plt.show()

# %% [markdown]
# ## Distribution of ratios of overtime worked vs. overtime paid. Finding potential outliers in the court OT database. This has been done for the year 2022 and can be done similarly for each year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data for the specific year
file_path = 'Court_Overtime_2021_-_2022_ytd.xlsx'
xls = pd.ExcelFile(file_path)
df = pd.read_excel(xls, '2022 ytd')

# Calculate the ratio of overtime worked (WRKDHRS) vs. overtime paid (OTHOURS)
df['Overtime_Ratio'] = df['WRKDHRS'] / df['OTHOURS']

# Rearrange the DataFrame based on 'NAME'
df = df.sort_values(by='NAME')

# Calculate the 'Average_Overtime_Ratio' for each 'NAME'
df['Average_Overtime_Ratio'] = df.groupby('NAME')['Overtime_Ratio'].transform('mean')

# Summary statistics
ratio_mean = df['Overtime_Ratio'].mean()
ratio_median = df['Overtime_Ratio'].median()
ratio_std = df['Overtime_Ratio'].std()

# Create a box plot to identify outliers
plt.figure(figsize=(8, 6))
plt.boxplot(df['Overtime_Ratio'], vert=False)
plt.title('Distribution of Overtime Ratios (2022)')
plt.xlabel('Overtime Ratio (WRKDHRS / OTHOURS)')
plt.grid(True)

# Print summary statistics
print(f"Mean Overtime Ratio: {ratio_mean:.2f}")
print(f"Median Overtime Ratio: {ratio_median:.2f}")
print(f"Standard Deviation of Overtime Ratio: {ratio_std:.2f}")

# Remove duplicate 'NAME' entries, keeping only the first occurrence
outliers = df.drop_duplicates(subset='NAME', keep='first')

# After visualizing the above plot, we set a threshold to identify potential outliers
# we set the threshold to 0.1, which means a person actually works 1 hour for every 10 hours they get paid
threshold = 0.1

# Identify potential outliers based on the threshold
outliers = outliers[outliers['Average_Overtime_Ratio'] < threshold]
outliers = outliers[['NAME', 'Average_Overtime_Ratio']]
print("Potential Outliers:")
print(outliers)

plt.show()
# Out:
# Mean Overtime Ratio: 0.38
# Median Overtime Ratio: 0.25
# Standard Deviation of Overtime Ratio: 0.29
# Potential Outliers:
#                             NAME  Average_Overtime_Ratio
# 14431  Agudelo-Echevarria,Marily                0.062500
# 8063           Becker,Matthew F.                0.093750
# 14740      Charles-Sampson,Azadi                0.093750
# 13188            Crabbe,David D.                0.093750
# 10355           Fantaroni,Evan M                0.062500
# 581                Foley,James M                0.093750
# 5035        Hyppolite,Jonathan A                0.062500
# 13884            Lawless,Timothy                0.093750
# 6697       Legacy,Mary Katherine                0.062500
# 14836      Lonergan,Ryan Charles                0.093750
# 6592                Mendes,Kevin                0.062500
# 14832          Milton,Christa A.                0.062500
# 8293         Murphy,Daniel Brian                0.062500
# 1745               Powell,Nadine                0.093750
# 4622              Ross,Allison D                0.062500
# 6696    Samuel-Lenehan,Angelique                0.062500
# 9943    Van Orman,Haley Margaret                0.062500
# 13950               West,Shawn L                0.062500
# 7061             Yanovitch,Scott                0.083333
